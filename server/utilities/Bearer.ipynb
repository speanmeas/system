# %%
import os
if not hasattr(os, "_cwd"):
    os.chdir("../../")
    os._cwd = True

# %%
import os
import sys


sys.path.append(os.getcwd())


from fastapi.security import *


bearer = OAuth2PasswordBearer(tokenUrl="credential/signin")
# Out:
# ['assets\\about', 'assets\\courses']
